# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import Analisa_Harga_Pangan_Seluruh_Indonesia_2018_2019_Part_1_Data_Analysis as DA_I

# %% [markdown]
# Analisa Harga Pangan Tahun 2018 dan 2019 di Indonesia (Data Harian Sepanjang Tahun)
#
# Bagian II Data Visualization using Matplotlib and Seaborn

# %%
list_daerah = ['aceh', 'bali', 'banten', 'bengkulu', 'diy', 'dki_jakarta', 'gorontalo', 'jabar', 'jambi', 'jateng', 'jatim', 
              'kalbar', 'kalsel', 'kalteng', 'kaltim', 'kalut', 'kepri', 'kepulauan_bangka_belitung', 'lampung', 'maluku',
               'malut', 'ntb', 'ntt', 'papua', 'papua_barat', 'riau', 'sulbar', 'sulsel', 'sulteng', 'sultra', 'sulut', 
               'sumbar', 'sumsel', 'sumut']
#year list
year = ['2018', '2019']

#commodity list
commodity_all = ['Bawang Merah', 'Bawang Putih', 'Beras', 'Cabai Merah',
       'Cabai Rawit', 'Daging Ayam', 'Daging Sapi', 'Gula Pasir',
       'Minyak Goreng', 'Telur Ayam']

# %%
#histogram

#this function for histogram of 1 selected province, be it by years or all years  
def histogram_province(data_frame, date=None, province=None, figname=None, against=False, save=False): #this function for histogram of 1 selected province
    list_ax2 = [0, 'ax1', 'ax2', 'ax3', 'ax4', 'ax5', 'ax6', 'ax7', 'ax8', 'ax9', 'ax10']
    columns_df2 = [0, 'Bawang Merah', 'Bawang Putih', 'Beras', 'Cabai Merah', 'Cabai Rawit', 
                   'Daging Ayam', 'Daging Sapi', 'Gula Pasir', 'Minyak Goreng', 'Telur Ayam']
    
    #for normal histogram, which compare commodity side by side 
    if against == False:
        #histogram base on year input by user
        if date == '2018' or date =='2019':
            fig = plt.figure(figsize=(20, 10))
            for i in range(1, 11):
                list_ax2[i] = plt.subplot(2, 5, i)
                plt.hist(data_frame[date][province][columns_df2[i]])#, bins=range(len(df_pivot['Bawang Merah'])))
                #list_ax[i].set_xticks(range(len(df_pivot)))
                #list_ax[i].set_xticklabels(df_pivot['Hari'])
                plt.title(columns_df2[i])
                #plt.xticks(rotation=90)
            plt.subplots_adjust(top=0.946, bottom=0.059, left=0.059, right=0.989, hspace=0.228, wspace=0.556)
            plt.tight_layout()
            fig.suptitle(figname+' '+date, fontsize=16, y=1.03)
            if save == True:
                plt.savefig(figname+' histogram ' + date+'.png')
            plt.show()
            return
        
        #histogram all year
        year = ['2018', '2019']
        if date == 'all':
            for i in range(len(year)):
                figure = plt.figure(figsize=(20, 10))
                for x in range(1, 11):
                    list_ax2[x] = plt.subplot(2, 5,x)
                    plt.hist(data_frame[year[i]][province][columns_df2[x]])#, bins=range(len(df_pivot['Bawang Merah'])))
                    #list_ax[i].set_xticks(range(len(df_pivot)))
                    #list_ax[i].set_xticklabels(df_pivot['Hari'])
                    plt.title(columns_df2[x])
                    #plt.xticks(rotation=90)
                plt.subplots_adjust(top=0.946, bottom=0.059, left=0.059, right=0.989, hspace=0.228, wspace=0.556)
                figure.suptitle(figname+' '+year[i], fontsize=16, y=1.03)
                plt.tight_layout()
                if save == True:
                    plt.savefig('E:\\for github\\harga pangan indo 2019\\all_fig\\' + figname +'_histogram_all_' + year[i]+ '.png', bbox_inches = "tight")
                plt.show()        
            return
        
    #below is histogram if the user want to compare histograms by putting them in one plot
    if against == True:
        fig = plt.figure(figsize=(20, 10))
        for i in range(1, 11):
            list_ax2[i] = plt.subplot(2, 5, i)
            plt.hist(data_frame['2018'][province][columns_df2[i]], density=True, histtype='step', label='2018')#, bins=range(len(df_pivot['Bawang Merah'])))
            plt.hist(data_frame['2019'][province][columns_df2[i]], density=True, histtype='step', label= '2019')
            #list_ax[i].set_xticks(range(len(df_pivot)))
            #list_ax[i].set_xticklabels(df_pivot['Hari'])
            plt.title(columns_df2[i])
            #plt.xticks(rotation=90)
            plt.legend()
        plt.subplots_adjust(top=0.946, bottom=0.059, left=0.059, right=0.989, hspace=0.228, wspace=0.556)
        plt.tight_layout()
        fig.suptitle(figname+' histogram 2018 & 2019', fontsize=16, y=1.03)
        if save == True:
            plt.savefig(figname+' histogram 2018 & 2019.png')
        plt.show()
        return
    
    
#this function is for histogram of all provinces all at once, be it by year or all years  
#be very careful when using this, this is for accesing all provinces histograms all at once
def hist_show_all_provinces(dataframe, year=None, against=False, save=False): 
    list_daerah = ['aceh', 'bali', 'banten', 'bengkulu', 'diy', 'dki_jakarta', 'gorontalo', 'jabar', 'jambi', 'jateng', 'jatim', 
              'kalbar', 'kalsel', 'kalteng', 'kaltim', 'kalut', 'kepri', 'kepulauan_bangka_belitung', 'lampung', 'maluku',
               'malut', 'ntb', 'ntt', 'papua', 'papua_barat', 'riau', 'sulbar', 'sulsel', 'sulteng', 'sultra', 'sulut', 
               'sumbar', 'sumsel', 'sumut']
    list_daerah2 = ['Aceh', 'Bali', 'Banten', 'Bengkulu', 'Daerah Istimewa Yogyakarta', 'DKI Jakarta', 'Gorontalo', 'Jawa Barat', 
                'Jambi', 'Jawa Tengah', 'Jawa Timur', 'Kalimantan Barat', 'Kalimantan Selatan', 'Kalimantan Tengah', 
                'Kalimantan Timur', 'Kalimantan Utara', 'Kepulauan Riau', 'Kepulauan Bangka Belitung', 'Lampung', 'Maluku',
               'Maluku Utara', 'Nusa Tenggara Barat', 'Nusa Tenggara Timur', 'Papua', 'Papua Barat', 'Riau', 
                'Sulawesi Barat', 'Sulawesi Selatan', 'Sulawesi Tengah', 'Sulawesi Tenggara', 'Sulawesi Utara', 
                'Sumatera Barat', 'Sumatera Selatan', 'Sumatera Utara']
    if against == False:
        if year == '2018' or year == '2019':
            for i in range(len(list_daerah)):
                histogram_province(dataframe, year, list_daerah[i], figname=list_daerah2[i], save=save) 
        elif year == 'all':
            for i in range(len(list_daerah)):
                histogram_province(dataframe, 'all', list_daerah[i], figname=list_daerah2[i], save=save)
    elif against == True:
        for i in range(len(list_daerah)):
            histogram_province(dataframe, province=list_daerah[i], figname=list_daerah2[i], against=against, save=save) 

#examine 1 province histogram , both years           
#histogram_province(DA_I.all_data_frame_pivot, 'all', 'jambi', figname='Jambi', save=False)

#examine 1 province histogram , against years          
#histogram_province(DA_I.all_data_frame_pivot,  province='jambi', figname='Jambi',  against=True, save=False)

#examine all provinces histograms all at once, both years side by side
#hist_show_all_provinces(DA_I.all_data_frame_pivot, year='all', save=True)

#examine all provinces histograms all at once, against years   
#hist_show_all_provinces(DA_I.all_data_frame_pivot, against=True, save=True)

#success

# %%
#Heatmap
#this function for heatmap of 1 selected province, be it by years or all years  
def heatmap_province(data_frame, date, province, figname, save=False):
    if date == '2018' or date == '2019':
        figure_o = plt.figure(figsize=(20, 10))
        c= data_frame[date][province][['Bawang Merah', 'Bawang Putih', 'Beras', 'Cabai Merah', 'Cabai Rawit', 'Daging Ayam', 'Daging Sapi', 'Gula Pasir','Minyak Goreng', 'Telur Ayam']].corr()
        ax = sns.heatmap(c,cmap="BrBG",annot=True)
        ax.set_title('Heatmap ' + figname +' ' + date)
        #figure_o.suptitle(list_daerah2[i], fontsize=30)
        #figure_o.subplots_adjust(top=0.91)
        if save == True:
            plt.savefig('E:\\for github\harga pangan indo 2019\savefig\\'+figname +'_heatmap_' + date+ '.png')
        plt.show()
        return
    year = ['2018', '2019']
    if date == 'all':
        for i in range(len(year)):
            figure_o = plt.figure(figsize=(20, 10))
            c= data_frame[year[i]][province][['Bawang Merah', 'Bawang Putih', 'Beras', 'Cabai Merah', 'Cabai Rawit', 'Daging Ayam', 'Daging Sapi', 'Gula Pasir','Minyak Goreng', 'Telur Ayam']].corr()
            ax = sns.heatmap(c,cmap="BrBG",annot=True)
            ax.set_title('Heatmap ' +figname+' '+ year[i])
            #figure_o.subplots_adjust(top=0.91)
            if save == True:
                plt.savefig('E:\\for github\\harga pangan indo 2019\\all_fig\\' + figname +'_heatmap_all_' + year[i]+ '.png', bbox_inches = "tight")
            plt.show()
        return
    
    
#this function is for heatmap of all provinces all at once, be it by year or all years  
#be very careful when using this, this is for accesing all provinces histograms all at once
def heatmap_show_all_provinces(dataframe, year, save=False): 
    list_daerah = ['aceh', 'bali', 'banten', 'bengkulu', 'diy', 'dki_jakarta', 'gorontalo', 'jabar', 'jambi', 'jateng', 'jatim', 
              'kalbar', 'kalsel', 'kalteng', 'kaltim', 'kalut', 'kepri', 'kepulauan_bangka_belitung', 'lampung', 'maluku',
               'malut', 'ntb', 'ntt', 'papua', 'papua_barat', 'riau', 'sulbar', 'sulsel', 'sulteng', 'sultra', 'sulut', 
               'sumbar', 'sumsel', 'sumut']
    list_daerah2 = ['Aceh', 'Bali', 'Banten', 'Bengkulu', 'Daerah Istimewa Yogyakarta', 'DKI Jakarta', 'Gorontalo', 'Jawa Barat', 
                'Jambi', 'Jawa Tengah', 'Jawa Timur', 'Kalimantan Barat', 'Kalimantan Selatan', 'Kalimantan Tengah', 
                'Kalimantan Timur', 'Kalimantan Utara', 'Kepulauan Riau', 'Kepulauan Bangka Belitung', 'Lampung', 'Maluku',
               'Maluku Utara', 'Nusa Tenggara Barat', 'Nusa Tenggara Timur', 'Papua', 'Papua Barat', 'Riau', 
                'Sulawesi Barat', 'Sulawesi Selatan', 'Sulawesi Tengah', 'Sulawesi Tenggara', 'Sulawesi Utara', 
                'Sumatera Barat', 'Sumatera Selatan', 'Sumatera Utara']
    if year == '2018' or year == '2019':
        for i in range(len(list_daerah)):
            heatmap_province(dataframe, year, list_daerah[i], figname=list_daerah2[i], save=save) 
    elif year == 'all':
        for i in range(len(list_daerah)):
            heatmap_province(dataframe, 'all', list_daerah[i], figname=list_daerah2[i], save=save) 
            
#examine 1 province            
#heatmap_province(DA_I.all_data_frame_pivot, 'all', 'jateng', figname= 'Jawa Tengah',save=False)                  

#examine all provinces heatmaps all at once, both years   
#heatmap_show_all_provinces(DA_I.all_data_frame_pivot, 'all', save=True)

#succeess

# %%
#Line PLot

#this function for lineplot of 1 selected province, be it by years or all years  
def line_plot_province(data_frame, date=None, province=None, figname=None, against=False, save=False):
    list_ax = [0, 'ax1', 'ax2', 'ax3', 'ax4', 'ax5', 'ax6', 'ax7', 'ax8', 'ax9', 'ax10']
    columns_df = [0, 'Bawang Merah', 'Bawang Putih', 'Beras', 'Cabai Merah',
       'Cabai Rawit', 'Daging Ayam', 'Daging Sapi', 'Gula Pasir',
       'Minyak Goreng', 'Telur Ayam']
    #plot per year all commodity
    if against == False:
        if date == '2018' or date == '2019':
            fig = plt.figure(figsize=(20, 10))
            for i in range(1, 11):
                list_ax[i] = plt.subplot(2, 5, i)
                plt.plot(range(len(data_frame[date][province])), data_frame[date][province][columns_df[i]])
                #list_ax[i].set_xticks(range(52))
                #list_ax[i].set_xticklabels(range(1, 13))
                plt.ylabel('Harga (Rp)')
                plt.title(columns_df[i])
                plt.xticks(rotation=90)
                plt.xlabel('Jan - Des '+date)
                plt.xticks([])
            plt.subplots_adjust(top=0.946, bottom=0.059, left=0.059, right=0.989, hspace=0.228, wspace=0.556)
            plt.tight_layout()
            fig.suptitle(figname +' '+date, fontsize=16, y=1.03)
            if save == True:
                plt.savefig(figname+' lineplot '+ date+' .png')
            plt.show()
            return
        #plot all year
        year = ['2018', '2019']
        if date == 'all':
            for x in range(len(year)):
                fig = plt.figure(figsize=(20, 10))
                for i in range(1, 11):
                    list_ax[i] = plt.subplot(2, 5, i)
                    plt.plot(range(len(data_frame[year[x]][province])), data_frame[year[x]][province][columns_df[i]])
                    #list_ax[i].set_xticks(range(52))
                    #list_ax[i].set_xticklabels(range(1, 13))
                    plt.ylabel('Harga (Rp)')
                    plt.title(columns_df[i])
                    plt.xticks(rotation=90)
                    plt.xlabel('Jan - Des '+year[x])
                    plt.xticks([])
                plt.subplots_adjust(top=0.946, bottom=0.059, left=0.059, right=0.989, hspace=0.228, wspace=0.556)
                plt.tight_layout()
                fig.suptitle(figname+' '+year[x], fontsize=16, y=1.03)
                plt.show()
            if save == True:
                plt.savefig(figname+' lineplot all years.png')
        return
    
    #plotting againts years
    elif against == True:
        fig = plt.figure(figsize=(20, 10))
        for i in range(1, 11):
            list_ax[i] = plt.subplot(2, 5, i)
            plt.plot(range(len(data_frame['2018'][province])), data_frame['2018'][province][columns_df[i]], label='2018')
            plt.plot(range(len(data_frame['2019'][province])), data_frame['2019'][province][columns_df[i]], label='2019')
            #list_ax[i].set_xticks(range(52))
            #list_ax[i].set_xticklabels(range(1, 13))
            plt.ylabel('Harga (Rp)')
            plt.title(columns_df[i])
            plt.xticks(rotation=90)
            plt.xlabel('Jan - Des 2018 & 2019')
            plt.xticks([])
            plt.legend()
        plt.subplots_adjust(top=0.946, bottom=0.059, left=0.059, right=0.989, hspace=0.228, wspace=0.556)
        plt.tight_layout()
        fig.suptitle(figname +' line plot 2018 & 2019', fontsize=16, y=1.03)
        if save == True:
            plt.savefig(figname+' line plot 2018 & 2019.png')
        plt.show()
        return
    
    
#this function is for lineplot of all provinces all at once, be it by year or all years  
#be very careful when using this, this is for accesing all provinces histograms all at once
def lineplot_show_all_provinces(dataframe, year=None, against=False, save=False): 
    list_daerah = ['aceh', 'bali', 'banten', 'bengkulu', 'diy', 'dki_jakarta', 'gorontalo', 'jabar', 'jambi', 'jateng', 'jatim', 
              'kalbar', 'kalsel', 'kalteng', 'kaltim', 'kalut', 'kepri', 'kepulauan_bangka_belitung', 'lampung', 'maluku',
               'malut', 'ntb', 'ntt', 'papua', 'papua_barat', 'riau', 'sulbar', 'sulsel', 'sulteng', 'sultra', 'sulut', 
               'sumbar', 'sumsel', 'sumut']
    list_daerah2 = ['Aceh', 'Bali', 'Banten', 'Bengkulu', 'Daerah Istimewa Yogyakarta', 'DKI Jakarta', 'Gorontalo', 'Jawa Barat', 
                'Jambi', 'Jawa Tengah', 'Jawa Timur', 'Kalimantan Barat', 'Kalimantan Selatan', 'Kalimantan Tengah', 
                'Kalimantan Timur', 'Kalimantan Utara', 'Kepulauan Riau', 'Kepulauan Bangka Belitung', 'Lampung', 'Maluku',
               'Maluku Utara', 'Nusa Tenggara Barat', 'Nusa Tenggara Timur', 'Papua', 'Papua Barat', 'Riau', 
                'Sulawesi Barat', 'Sulawesi Selatan', 'Sulawesi Tengah', 'Sulawesi Tenggara', 'Sulawesi Utara', 
                'Sumatera Barat', 'Sumatera Selatan', 'Sumatera Utara']
    if against == False:
        if year == '2018' or year == '2019':
            for i in range(len(list_daerah)):
                line_plot_province(dataframe, year, list_daerah[i], figname=list_daerah2[i], save=save) 
        elif year == 'all':
            for i in range(len(list_daerah)):
                line_plot_province(dataframe, 'all', list_daerah[i], figname=list_daerah2[i], save=save)
                
    elif against == True:
        for i in range(len(list_daerah)):
                line_plot_province(dataframe, province=list_daerah[i], figname=list_daerah2[i], against=against, save=save)

            
#examine 1 province            
#line_plot_province(DA_I.all_data_frame_pivot, 'all', 'sultra', figname='Sulawesi Utara', save=False)

#examine 1 province, against            
#line_plot_province(DA_I.all_data_frame_pivot, province='sultra', figname='Sulawesi Utara', against=True, save=False)   

#examine all provinces heatmaps all at once, both years   
#lineplot_show_all_provinces(DA_I.all_data_frame_pivot, 'all', save=False) 

#examine all provinces heatmaps all at once, against years   
#lineplot_show_all_provinces(DA_I.all_data_frame_pivot, against=True, save=False) 


#succeess

# %%
#bar plot
#this function for barplot of 1 selected province, be it by years or all years 
def bar_plot_province(data_frame, date, province, save=False):
    if date == '2018' or date == '2019':
        f, ax = plt.subplots(figsize=(20, 10)) 
        ax = sns.barplot(data=data_frame[date][province], x='Komoditas', y='Harga', hue='Tanggal')
        plt.ylabel('Harga (Rp)')
        plt.xlabel('Komoditas (365 hari)')
        ax.get_legend().remove()
        #plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        #plt.savefig('Bar.png')
        f.suptitle(province +' ' +date, fontsize=16, y= 0.93)
        plt.show()
        return
    year = ['2018', '2019']
    if date == 'all':
        for i in range(len(year)):
            f, ax = plt.subplots(figsize=(20, 10)) 
            ax = sns.barplot(data=data_frame[year[i]][province], x='Komoditas', y='Harga', hue='Tanggal')
            plt.ylabel('Harga (Rp)')
            plt.xlabel('Komoditas (365 hari)')
            ax.get_legend().remove()
            f.suptitle(province+' '+year[i], fontsize=16, y= 0.93)
            #plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
            #plt.savefig('Bar.png')
            plt.show()
        return

#this function is for barplot of all provinces all at once, be it by year or all years  
#be very careful when using this, this is for accesing all provinces histograms all at once    
def barplot_show_all_provinces(dataframe, year, save=False): 
    list_daerah = ['aceh', 'bali', 'banten', 'bengkulu', 'diy', 'dki_jakarta', 'gorontalo', 'jabar', 'jambi', 'jateng', 'jatim', 
              'kalbar', 'kalsel', 'kalteng', 'kaltim', 'kalut', 'kepri', 'kepulauan_bangka_belitung', 'lampung', 'maluku',
               'malut', 'ntb', 'ntt', 'papua', 'papua_barat', 'riau', 'sulbar', 'sulsel', 'sulteng', 'sultra', 'sulut', 
               'sumbar', 'sumsel', 'sumut']
    if year == '2018' or year == '2019':
        for i in range(len(list_daerah)):
            bar_plot_province(dataframe, year, list_daerah[i], save=save) 
    elif year == 'all':
        for i in range(len(list_daerah)):
            bar_plot_province(dataframe, 'all', list_daerah[i], save=save)

            
#examine 1 province            
#bar_plot_province(DA_I.all_data_frame_melt, 'all', 'kaltim', save=False)                  

#examine all provinces heatmaps all at once, both years   
#barplot_show_all_provinces(DA_I.all_data_frame_melt, 'all', save=False) 
#succeess

# %%
#boxplot

#this function for boxplot of 1 selected province, be it by years or all years 
def box_plot_province(data_frame, date, province, save=False):
    if date == '2018' or date == '2019':
        fig = plt.figure(figsize=(20, 10))
        ax = plt.subplot()
        sns.boxplot(data=data_frame[date][province], x='Komoditas', y='Harga')
        fig.suptitle(province +' '+date, fontsize=16, y= 0.93)
        plt.show()
        return
    year = ['2018', '2019']
    if date == 'all':
        for i in range(len(year)):
            fig = plt.figure(figsize=(20, 10))
            ax = plt.subplot()
            sns.boxplot(data=data_frame[year[i]][province], x='Komoditas', y='Harga')
            fig.suptitle(province +' '+year[i], fontsize=16, y= 0.93)
            plt.show()
        return

    
#this function is for boxplot of all provinces all at once, be it by year or all years  
#be very careful when using this, this is for accesing all provinces histograms all at once    
def boxplot_show_all_provinces(dataframe, year, save=False): 
    list_daerah = ['aceh', 'bali', 'banten', 'bengkulu', 'diy', 'dki_jakarta', 'gorontalo', 'jabar', 'jambi', 'jateng', 'jatim', 
              'kalbar', 'kalsel', 'kalteng', 'kaltim', 'kalut', 'kepri', 'kepulauan_bangka_belitung', 'lampung', 'maluku',
               'malut', 'ntb', 'ntt', 'papua', 'papua_barat', 'riau', 'sulbar', 'sulsel', 'sulteng', 'sultra', 'sulut', 
               'sumbar', 'sumsel', 'sumut']
    if year == '2018' or year == '2019':
        for i in range(len(list_daerah)):
            box_plot_province(dataframe, year, list_daerah[i], save=save) 
    elif year == 'all':
        for i in range(len(list_daerah)):
            box_plot_province(dataframe, 'all', list_daerah[i], save=save)

            
#examine 1 province            
#box_plot_province(DA_I.all_data_frame_melt, 'all', 'ntb', save=False)                  

#examine all provinces heatmaps all at once, both years   
#boxplot_show_all_provinces(DA_I.all_data_frame_melt, 'all', save=False) 
#succeess

# %%
#continue with visualization for each commodity with df commodity

# %% [markdown]
# Now we have visualize every commodities in each province (10 commodities in one province for each province)
#
# But, is this enough to produce insight?
#
# I dont think so, we need to also visualize each commodity compare to each province
#
# so later we can compare certain provinces commodity price against other provinces

# %%
#histogram for commodity

commodity_all = ['Bawang Merah', 'Bawang Putih', 'Beras', 'Cabai Merah',
       'Cabai Rawit', 'Daging Ayam', 'Daging Sapi', 'Gula Pasir',
       'Minyak Goreng', 'Telur Ayam']

#this function for histogram of 1 selected commodity, be it by years or all years  
def histogram_commodity(data_frame, date, commodity,save=False): 
    list_ax2 = [0, 'ax1', 'ax2', 'ax3', 'ax4', 'ax5', 'ax6', 'ax7', 'ax8', 'ax9', 'ax10',  'ax11', 'ax12', 'ax13', 'ax14',
               'ax15', 'ax16', 'ax17', 'ax18', 'ax19', 'ax20', 'ax21', 'ax22', 'ax23', 'ax24', 'ax25', 'ax26', 'ax27',
               'ax128', 'ax29', 'ax30', 'ax31', 'ax32', 'ax33', 'ax34']
    columns_df2 = [0, 'Aceh', 'Bali', 'Banten', 'Bengkulu', 'Daerah Istimewa Yogyakarta', 'DKI Jakarta', 'Gorontalo', 'Jawa Barat', 
                'Jambi', 'Jawa Tengah', 'Jawa Timur', 'Kalimantan Barat', 'Kalimantan Selatan', 'Kalimantan Tengah', 
                'Kalimantan Timur', 'Kalimantan Utara', 'Kepulauan Riau', 'Kepulauan Bangka Belitung', 'Lampung', 'Maluku',
               'Maluku Utara', 'Nusa Tenggara Barat', 'Nusa Tenggara Timur', 'Papua', 'Papua Barat', 'Riau', 
                'Sulawesi Barat', 'Sulawesi Selatan', 'Sulawesi Tengah', 'Sulawesi Tenggara', 'Sulawesi Utara', 
                'Sumatera Barat', 'Sumatera Selatan', 'Sumatera Utara']
    #for 1 selected year
    if date == '2018' or date =='2019':
        fig = plt.figure(figsize=(20, 25))
        for i in range(1, 35):
            list_ax2[i] = plt.subplot(7, 5, i)
            plt.hist(data_frame[date][commodity][columns_df2[i]])#, bins=range(len(df_pivot['Bawang Merah'])))
            #list_ax[i].set_xticks(range(len(df_pivot)))
            #list_ax[i].set_xticklabels(df_pivot['Hari'])
            plt.title(columns_df2[i])
            #plt.xticks(rotation=90)
        plt.subplots_adjust(top=0.946, bottom=0.059, left=0.059, right=0.989, hspace=0.228, wspace=0.556)
        plt.tight_layout()
        fig.suptitle(commodity+' '+date, fontsize=16, y=1.009)
        if save == True:
            plt.savefig(commodity+' histogram ' + date+'.png')
        plt.show()
        return
    year = ['2018', '2019']
    #for all years
    if date == 'all':
        for i in range(len(year)):
            figure = plt.figure(figsize=(20, 25))
            for x in range(1, 35):
                list_ax2[x] = plt.subplot(7, 5,x)
                plt.hist(data_frame[year[i]][commodity][columns_df2[x]])#, bins=range(len(df_pivot['Bawang Merah'])))
                #list_ax[i].set_xticks(range(len(df_pivot)))
                #list_ax[i].set_xticklabels(df_pivot['Hari'])
                plt.title(columns_df2[x])
                #plt.xticks(rotation=90)
            plt.subplots_adjust(top=0.946, bottom=0.059, left=0.059, right=0.989, hspace=0.228, wspace=0.556)
            figure.suptitle(commodity+' '+year[i], fontsize=16, y=1.009)
            plt.tight_layout()
            plt.show()
        if save == True:
            plt.savefig(commodity+' histogram all years.png')
            
        return

#this function is for histogram of all commodities all at once, be it by year or all years  
#be very careful when using this, this is for accesing all commodities histograms all at once
def hist_show_all_commodities(dataframe, year, save=False): 
    commodity_all = ['Bawang Merah', 'Bawang Putih', 'Beras', 'Cabai Merah',
       'Cabai Rawit', 'Daging Ayam', 'Daging Sapi', 'Gula Pasir',
       'Minyak Goreng', 'Telur Ayam']
    if year == '2018' or year == '2019':
        for i in range(len(commodity_all)):
            histogram_commodity(dataframe, year, commodity_all[i], save=save) 
    elif year == 'all':
        for i in range(len(commodity_all)):
            histogram_province(dataframe, 'all', commodity_all[i], save=save)     
    
#examine
#histogram_commodity(DA_I.all_data_frame_pivot_commodity, 'all', 'Cabai Rawit',save=False)

#hist_show_all_commodities(DA_I.all_data_frame_pivot_commodity, 'all', save=False)
#succees

# %%
#Heatmap for commodity

#this function for heatmap of 1 selected province, be it by years or all years  
def heatmap_commodity(data_frame, date, commodity, save=False):
    if date == '2018' or date == '2019':
        figure_o = plt.figure(figsize=(25, 25))
        c= data_frame[date][commodity][['Aceh', 'Bali', 'Banten', 'Bengkulu', 'Daerah Istimewa Yogyakarta', 'DKI Jakarta', 'Gorontalo', 'Jawa Barat', 
                'Jambi', 'Jawa Tengah', 'Jawa Timur', 'Kalimantan Barat', 'Kalimantan Selatan', 'Kalimantan Tengah', 
                'Kalimantan Timur', 'Kalimantan Utara', 'Kepulauan Riau', 'Kepulauan Bangka Belitung', 'Lampung', 'Maluku',
               'Maluku Utara', 'Nusa Tenggara Barat', 'Nusa Tenggara Timur', 'Papua', 'Papua Barat', 'Riau', 
                'Sulawesi Barat', 'Sulawesi Selatan', 'Sulawesi Tengah', 'Sulawesi Tenggara', 'Sulawesi Utara', 
                'Sumatera Barat', 'Sumatera Selatan', 'Sumatera Utara']].corr()
        ax = sns.heatmap(c,cmap="BrBG",annot=True)
        ax.set_title('Heatmap ' + commodity +' ' + date)
        #figure_o.suptitle(list_daerah2[i], fontsize=30)
        #figure_o.subplots_adjust(top=0.91)
        if save == True:
            plt.savefig('E:\\for github\harga pangan indo 2019\savefig\\'+province +'_heatmap_' + date+ '.png')
        plt.show()
        return
    year = ['2018', '2019']
    if date == 'all':
        for i in range(len(year)):
            figure_o = plt.figure(figsize=(25, 25))
            c= data_frame[year[i]][commodity][['Aceh', 'Bali', 'Banten', 'Bengkulu', 'Daerah Istimewa Yogyakarta', 'DKI Jakarta', 'Gorontalo', 'Jawa Barat', 
                'Jambi', 'Jawa Tengah', 'Jawa Timur', 'Kalimantan Barat', 'Kalimantan Selatan', 'Kalimantan Tengah', 
                'Kalimantan Timur', 'Kalimantan Utara', 'Kepulauan Riau', 'Kepulauan Bangka Belitung', 'Lampung', 'Maluku',
               'Maluku Utara', 'Nusa Tenggara Barat', 'Nusa Tenggara Timur', 'Papua', 'Papua Barat', 'Riau', 
                'Sulawesi Barat', 'Sulawesi Selatan', 'Sulawesi Tengah', 'Sulawesi Tenggara', 'Sulawesi Utara', 
                'Sumatera Barat', 'Sumatera Selatan', 'Sumatera Utara']].corr()
            ax = sns.heatmap(c,cmap="BrBG",annot=True)
            ax.set_title('Heatmap ' +commodity+' '+ year[i])
            #figure_o.subplots_adjust(top=0.91)
            if save == True:
                plt.savefig('E:\\for github\harga pangan indo 2019\savefig\\'+ province+'_heatmap_' +year[i]+'.png')
            plt.show()
        return

#this function is for heatmap of all commodities all at once, be it by year or all years  
#be very careful when using this, this is for accesing all provinces histograms all at once
def heatmap_show_all_commodities(dataframe, year, save=False): 
    commodity_all = ['Bawang Merah', 'Bawang Putih', 'Beras', 'Cabai Merah',
       'Cabai Rawit', 'Daging Ayam', 'Daging Sapi', 'Gula Pasir',
       'Minyak Goreng', 'Telur Ayam']
    if year == '2018' or year == '2019':
        for i in range(len(commodity_all)):
            heatmap_commodity(dataframe, year, commodity_all[i], save=save) 
    elif year == 'all':
        for i in range(len(commodity_all)):
            heatmap_commodity(dataframe, 'all', commodity_all[i], save=save)      
#examine           
#heatmap_commodity(DA_I.all_data_frame_pivot_commodity, 'all', 'Gula Pasir', save=False) 

#heatmap_show_all_commodities(DA_I.all_data_frame_pivot_commodity, 'all', save=False)
#succees

# %%
#Line PLot commodity

#this function for lineplot of 1 selected commodity, be it by years or all years  
def line_plot_commodity(data_frame, date, commodity, save=False):
    list_ax = [0, 'ax1', 'ax2', 'ax3', 'ax4', 'ax5', 'ax6', 'ax7', 'ax8', 'ax9', 'ax10',  'ax11', 'ax12', 'ax13', 'ax14',
               'ax15', 'ax16', 'ax17', 'ax18', 'ax19', 'ax20', 'ax21', 'ax22', 'ax23', 'ax24', 'ax25', 'ax26', 'ax27',
               'ax128', 'ax29', 'ax30', 'ax31', 'ax32', 'ax33', 'ax34']
    columns_df = [0, 'Aceh', 'Bali', 'Banten', 'Bengkulu', 'Daerah Istimewa Yogyakarta', 'DKI Jakarta', 'Gorontalo', 'Jawa Barat', 
                'Jambi', 'Jawa Tengah', 'Jawa Timur', 'Kalimantan Barat', 'Kalimantan Selatan', 'Kalimantan Tengah', 
                'Kalimantan Timur', 'Kalimantan Utara', 'Kepulauan Riau', 'Kepulauan Bangka Belitung', 'Lampung', 'Maluku',
               'Maluku Utara', 'Nusa Tenggara Barat', 'Nusa Tenggara Timur', 'Papua', 'Papua Barat', 'Riau', 
                'Sulawesi Barat', 'Sulawesi Selatan', 'Sulawesi Tengah', 'Sulawesi Tenggara', 'Sulawesi Utara', 
                'Sumatera Barat', 'Sumatera Selatan', 'Sumatera Utara']
    if date == '2018' or date == '2019':
        fig = plt.figure(figsize=(20, 25))
        for i in range(1, 35):
            list_ax[i] = plt.subplot(7, 5, i)
            plt.plot(range(len(data_frame[date][commodity])), data_frame[date][commodity][columns_df[i]])
            #list_ax[i].set_xticks(range(52))
            #list_ax[i].set_xticklabels(range(1, 13))
            plt.ylabel('Harga (Rp)')
            plt.title(columns_df[i])
            plt.xticks(rotation=90)
            plt.xlabel('Jan - Des '+date)
            plt.xticks([])
        plt.subplots_adjust(top=0.946, bottom=0.059, left=0.059, right=0.989, hspace=0.228, wspace=0.556)
        plt.tight_layout()
        fig.suptitle(commodity +' '+date, fontsize=16, y=1.009)
        if save == True:
            plt.savefig(commodity+' lineplot '+ date+' .png')
        plt.show()
        return
    year = ['2018', '2019']
    if date == 'all':
        for x in range(len(year)):
            fig = plt.figure(figsize=(20, 25))
            for i in range(1, 35):
                list_ax[i] = plt.subplot(7, 5, i) #this means sublot has 7 rows, 5 columns, and at position i in figure
                plt.plot(range(len(data_frame[year[x]][commodity])), data_frame[year[x]][commodity][columns_df[i]])
                #list_ax[i].set_xticks(range(52))
                #list_ax[i].set_xticklabels(range(1, 13))
                plt.ylabel('Harga (Rp)')
                plt.title(columns_df[i])
                plt.xticks(rotation=90)
                plt.xlabel('Jan - Des '+year[x])
                plt.xticks([])
            plt.subplots_adjust(top=0.946, bottom=0.059, left=0.059, right=0.989, hspace=0.228, wspace=0.556)
            plt.tight_layout()
            fig.suptitle(commodity+' '+year[x], fontsize=16, y=1.009)
            plt.show()
        if save == True:
            plt.savefig(province+' lineplot all years.png')
        return

#this function is for linechart of all commodities all at once, be it by year or all years  
#be very careful when using this, this is for accesing all commodities linechart all at once
def line_plot_show_all_commodities(dataframe, year, save=False): 
    commodity_all = ['Bawang Merah', 'Bawang Putih', 'Beras', 'Cabai Merah',
       'Cabai Rawit', 'Daging Ayam', 'Daging Sapi', 'Gula Pasir',
       'Minyak Goreng', 'Telur Ayam']
    if year == '2018' or year == '2019':
        for i in range(len(commodity_all)):
            line_plot_commodity(dataframe, year, commodity_all[i], save=save) 
    elif year == 'all':
        for i in range(len(commodity_all)):
            line_plot_commodity(dataframe, 'all', commodity_all[i], save=save)      
#examine    
#line_plot_commodity(DA_I.all_data_frame_pivot_commodity, 'all', 'Daging Sapi', save=False)  

#line_plot_show_all_commodities(DA_I.all_data_frame_pivot_commodity, 'all', save=False)
#succees

# %%
#bar plot commodity

#this function for barplot of 1 selected commodity, be it by years or all years 
def bar_plot_province(data_frame, date, commodity, save=False):
    if date == '2018' or date == '2019':
        f, ax = plt.subplots(figsize=(20, 10)) 
        ax = sns.barplot(data=data_frame[date][commodity], x='Provinsi', y='Harga', hue='Tanggal')
        plt.ylabel('Harga (Rp)')
        plt.xlabel('Komoditas (365 hari)')
        plt.xticks(rotation=90)
        ax.get_legend().remove()
        #plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        #plt.savefig('Bar.png')
        f.suptitle(commodity +' ' +date, fontsize=16, y= 0.93)
        plt.show()
        return
    year = ['2018', '2019']
    if date == 'all':
        for i in range(len(year)):
            f, ax = plt.subplots(figsize=(20, 10)) 
            ax = sns.barplot(data=data_frame[year[i]][commodity], x='Provinsi', y='Harga', hue='Tanggal')
            plt.ylabel('Harga (Rp)')
            plt.xlabel('Komoditas (365 hari)')
            plt.xticks(rotation=90)
            ax.get_legend().remove()
            f.suptitle(commodity+' '+year[i], fontsize=16, y= 0.93)
            #plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
            #plt.savefig('Bar.png')
            plt.show()
        return
    
#this function is for bar plot of all commodities all at once, be it by year or all years  
#be very careful when using this, this is for accesing all commodities bar plot all at once
def bar_plot_show_all_commodities(dataframe, year, save=False): 
    commodity_all = ['Bawang Merah', 'Bawang Putih', 'Beras', 'Cabai Merah',
       'Cabai Rawit', 'Daging Ayam', 'Daging Sapi', 'Gula Pasir',
       'Minyak Goreng', 'Telur Ayam']
    if year == '2018' or year == '2019':
        for i in range(len(commodity_all)):
            bar_plot_province(dataframe, year, commodity_all[i], save=save) 
    elif year == 'all':
        for i in range(len(commodity_all)):
            bar_plot_province(dataframe, 'all', commodity_all[i], save=save)      
#examine           
#bar_plot_province(DA_I.all_data_frame_commodity_melt_fix, 'all', 'Bawang Merah', save=False) 

#bar_plot_show_all_commodities(DA_I.all_data_frame_commodity_melt_fix, 'all', save=False)
#succees

# %%
#boxplot commodity

#this function for boxplot of 1 selected commodity, be it by years or all years 
def box_plot_province(data_frame, date, commodity, save=False):
    if date == '2018' or date == '2019':
        fig = plt.figure(figsize=(20, 10))
        ax = plt.subplot()
        sns.boxplot(data=data_frame[date][commodity], x='Provinsi', y='Harga')
        plt.xticks(rotation=90)
        fig.suptitle(commodity +' '+date, fontsize=16)
        plt.show()
        return
    year = ['2018', '2019']
    if date == 'all':
        for i in range(len(year)):
            fig = plt.figure(figsize=(20, 10))
            ax = plt.subplot()
            sns.boxplot(data=data_frame[year[i]][commodity], x='Provinsi', y='Harga')
            plt.xticks(rotation=90)
            fig.suptitle(commodity +' '+year[i], fontsize=16)
            plt.show()
        return
    
#this function is for box plot of all commodities all at once, be it by year or all years  
#be very careful when using this, this is for accesing all commodities box plot all at once
def box_plot_show_all_commodities(dataframe, year, save=False): 
    commodity_all = ['Bawang Merah', 'Bawang Putih', 'Beras', 'Cabai Merah',
       'Cabai Rawit', 'Daging Ayam', 'Daging Sapi', 'Gula Pasir',
       'Minyak Goreng', 'Telur Ayam']
    if year == '2018' or year == '2019':
        for i in range(len(commodity_all)):
            box_plot_province(dataframe, year, commodity_all[i], save=save) 
    elif year == 'all':
        for i in range(len(commodity_all)):
            box_plot_province(dataframe, 'all', commodity_all[i], save=save)      
#examine           
#box_plot_province(DA_I.all_data_frame_commodity_melt_fix, 'all', 'Daging Ayam', save=False) 

#box_plot_show_all_commodities(DA_I.all_data_frame_commodity_melt_fix, 'all', save=False)
#succees

# %% [markdown]
# OKay, since this is visualization for 34 province, it wiil be to big to be displayed here
#
# I will put some of the visualization on the separate folder
#
# i dont have any insight yet, feel free to give me any
#
# and if you want to run this script on your local machines, just clone it
#
# and send me email if you want all CSV data
#
# s.adhitya.dimas@gmail.com
